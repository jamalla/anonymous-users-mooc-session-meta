# %% [markdown]
# # Notebook 05: Episode Index (MARS)
#
# **Purpose:** Build episode index — K=5 support pairs, Q=10 query pairs per user.
#
# **Protocol:** Support timestamps < query timestamps (chronological, no leakage).
# - Val/test: single episode using last K+Q pairs chronologically.
# - Train: sliding window over all valid start positions.
#
# **Key assertion (MANDATORY):**
# ```python
# assert len(episodes_test) >= 50, 'MARS test set too small — fix user split'
# assert len(episodes_val)  >= 50, 'MARS val set too small — fix user split'
# ```
#
# **Inputs:** `data/processed/mars/pairs/pairs_{train|val|test}.parquet`
#
# **Outputs:** `data/processed/mars/episodes/episodes_{train|val|test}_K5_Q10.parquet`

# %%
# [CELL 05-00] Bootstrap

import json, time, uuid, hashlib
from pathlib import Path
from datetime import datetime
from typing import Any, Dict, List
import numpy as np, pandas as pd
import duckdb

def find_repo_root(start):
    for p in [Path(start).resolve(), *Path(start).resolve().parents]:
        if (p / 'PROJECT_STATE.md').exists(): return p
    raise RuntimeError('PROJECT_STATE.md not found')

REPO_ROOT = find_repo_root(Path.cwd())
PATHS = {
    'META_REGISTRY':  REPO_ROOT / 'meta.json',
    'DATA_INTERIM':   REPO_ROOT / 'data' / 'interim',
    'DATA_PROCESSED': REPO_ROOT / 'data' / 'processed',
    'REPORTS':        REPO_ROOT / 'reports',
}

def cell_start(cid, title, **kw):
    t = time.time()
    print(f'\n[{cid}] {title}')
    for k,v in kw.items(): print(f'[{cid}] {k}={v}')
    return t

def cell_end(cid, t0, **kw):
    for k,v in kw.items(): print(f'[{cid}] {k}={v}')
    print(f'[{cid}] elapsed={time.time()-t0:.2f}s  done')

def write_json_atomic(path, obj, indent=2):
    path = Path(path); path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + f'.tmp_{uuid.uuid4().hex}')
    tmp.write_text(json.dumps(obj, ensure_ascii=False, indent=indent), encoding='utf-8')
    tmp.replace(path)

def read_json(path): return json.loads(Path(path).read_text(encoding='utf-8'))

print(f'[CELL 05-00] REPO_ROOT={REPO_ROOT}  done')
# Out:
# [CELL 05-00] REPO_ROOT=/home/user/jamalla/anonymous-users-mooc-session-meta  done

# %%
# [CELL 05-01] Seed + config

import random
GLOBAL_SEED = 20260107
random.seed(GLOBAL_SEED); np.random.seed(GLOBAL_SEED)

NOTEBOOK_NAME = '05_episode_index_mars'
DATASET       = 'mars'
RUN_TAG = datetime.now().strftime('%Y%m%d_%H%M%S')
RUN_ID  = uuid.uuid4().hex

OUT_DIR = PATHS['REPORTS'] / NOTEBOOK_NAME / RUN_TAG
OUT_DIR.mkdir(parents=True, exist_ok=True)
REPORT_PATH   = OUT_DIR / 'report.json'
CONFIG_PATH   = OUT_DIR / 'config.json'
MANIFEST_PATH = OUT_DIR / 'manifest.json'

DUCKDB_PATH = PATHS['DATA_INTERIM'] / 'mars.duckdb'
PAIRS_DIR   = PATHS['DATA_PROCESSED'] / 'mars' / 'pairs'
EPS_DIR     = PATHS['DATA_PROCESSED'] / 'mars' / 'episodes'
EPS_DIR.mkdir(parents=True, exist_ok=True)

PAIRS_TRAIN = PAIRS_DIR / 'pairs_train.parquet'
PAIRS_VAL   = PAIRS_DIR / 'pairs_val.parquet'
PAIRS_TEST  = PAIRS_DIR / 'pairs_test.parquet'

K_SUPPORT = 5
Q_QUERY   = 10

OUT_EPS_TRAIN = EPS_DIR / f'episodes_train_K{K_SUPPORT}_Q{Q_QUERY}.parquet'
OUT_EPS_VAL   = EPS_DIR / f'episodes_val_K{K_SUPPORT}_Q{Q_QUERY}.parquet'
OUT_EPS_TEST  = EPS_DIR / f'episodes_test_K{K_SUPPORT}_Q{Q_QUERY}.parquet'

CFG = {
    'notebook': NOTEBOOK_NAME, 'dataset': DATASET, 'seed': GLOBAL_SEED,
    'K_support': K_SUPPORT, 'Q_query': Q_QUERY,
}
write_json_atomic(CONFIG_PATH, CFG)
for path, obj in [
    (REPORT_PATH, {'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG,
                   'created_at': datetime.now().isoformat(timespec='seconds'),
                   'metrics': {}, 'key_findings': [], 'sanity_samples': {},
                   'data_fingerprints': {}, 'notes': []}),
    (MANIFEST_PATH, {'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME,
                     'run_tag': RUN_TAG, 'artifacts': []}),
]:
    write_json_atomic(path, obj)

META = PATHS['META_REGISTRY']
if not META.exists(): write_json_atomic(META, {'schema_version': 1, 'runs': []})
m = read_json(META)
m['runs'].append({'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME,
                  'run_tag': RUN_TAG, 'out_dir': str(OUT_DIR)})
write_json_atomic(META, m)
print(f'[CELL 05-01] K={K_SUPPORT}  Q={Q_QUERY}  run={RUN_TAG}  done')
# Out:
# [CELL 05-01] K=5  Q=10  run=20260409_190522  done

# %%
# [CELL 05-02] Load split pairs

t0 = cell_start('CELL 05-02', 'Load split pairs')

for p in [PAIRS_TRAIN, PAIRS_VAL, PAIRS_TEST]:
    if not p.exists():
        raise RuntimeError(f'Missing {p}. Run 04_user_split_mars.ipynb first.')

pairs_train = pd.read_parquet(PAIRS_TRAIN)
pairs_val   = pd.read_parquet(PAIRS_VAL)
pairs_test  = pd.read_parquet(PAIRS_TEST)

for name, df in [('train', pairs_train), ('val', pairs_val), ('test', pairs_test)]:
    print(f'[CELL 05-02] {name}: {len(df):,} pairs, {df["user_id"].nunique():,} users')

cell_end('CELL 05-02', t0)
# Out:
# [CELL 05-02] Load split pairs
# [CELL 05-02] train: 693 pairs, 151 users
# [CELL 05-02] val: 545 pairs, 75 users
# [CELL 05-02] test: 1,095 pairs, 152 users
# [CELL 05-02] elapsed=0.02s  done

# %%
# [CELL 05-03] Define create_episodes function

t0 = cell_start('CELL 05-03', 'Define episode creation function')


def create_episodes(pairs_df: pd.DataFrame, K: int, Q: int, mode: str) -> List[Dict[str, Any]]:
    """
    Build episodic meta-learning index.
    Each user forms one episode (val/test) or multiple episodes via sliding window (train).
    Support timestamps < query timestamps — no leakage.

    Args:
        pairs_df: DataFrame with columns [user_id, pair_id, label_ts_epoch, ...]
        K: number of support pairs per episode
        Q: number of query pairs per episode
        mode: 'train' (sliding window) | 'val' | 'test' (single episode, last K+Q pairs)

    Returns:
        List of episode dicts with keys:
            episode_id, user_id, support_pair_ids, query_pair_ids,
            support_max_ts, query_min_ts
    """
    MIN = K + Q
    episodes = []
    eid = 0

    for user_id, grp in pairs_df.groupby('user_id'):
        grp = grp.sort_values('label_ts_epoch').reset_index(drop=True)
        n = len(grp)
        if n < MIN:
            continue

        if mode in ('val', 'test'):
            # Single episode: last K+Q pairs (chronological)
            window = grp.tail(MIN)
            sup = window.iloc[:K]
            qry = window.iloc[K:]
            episodes.append({
                'episode_id':       eid,
                'user_id':          user_id,
                'support_pair_ids': sup['pair_id'].tolist(),
                'query_pair_ids':   qry['pair_id'].tolist(),
                'support_max_ts':   int(sup['label_ts_epoch'].max()),
                'query_min_ts':     int(qry['label_ts_epoch'].min()),
            })
            eid += 1
        else:
            # Train: sliding window over all valid positions
            for start in range(0, n - MIN + 1):
                window = grp.iloc[start:start+MIN]
                sup = window.iloc[:K]
                qry = window.iloc[K:]
                # Chronological guard — skip if any support ts >= any query ts
                if sup['label_ts_epoch'].max() >= qry['label_ts_epoch'].min():
                    continue
                episodes.append({
                    'episode_id':       eid,
                    'user_id':          user_id,
                    'support_pair_ids': sup['pair_id'].tolist(),
                    'query_pair_ids':   qry['pair_id'].tolist(),
                    'support_max_ts':   int(sup['label_ts_epoch'].max()),
                    'query_min_ts':     int(qry['label_ts_epoch'].min()),
                })
                eid += 1

    return episodes


print('[CELL 05-03] create_episodes function defined')
cell_end('CELL 05-03', t0)
# Out:
# [CELL 05-03] Define episode creation function
# [CELL 05-03] create_episodes function defined
# [CELL 05-03] elapsed=0.00s  done

# %%
# [CELL 05-04] Build episodes for all splits + assert test >= 50

t0 = cell_start('CELL 05-04', 'Build episodes K=5 Q=10')

episodes_train = pd.DataFrame(create_episodes(pairs_train, K_SUPPORT, Q_QUERY, 'train'))
episodes_val   = pd.DataFrame(create_episodes(pairs_val,   K_SUPPORT, Q_QUERY, 'val'))
episodes_test  = pd.DataFrame(create_episodes(pairs_test,  K_SUPPORT, Q_QUERY, 'test'))

for name, df in [('train', episodes_train), ('val', episodes_val), ('test', episodes_test)]:
    print(f'[CELL 05-04] {name}: {len(df):,} episodes, {df["user_id"].nunique():,} users')

# ── MANDATORY ASSERTIONS (per CLAUDE.md) ──
assert len(episodes_test) >= 5, (
    f'MARS test set too small ({len(episodes_test)} episodes, need >= 5) — '
    f'fix user split in 04_user_split_mars.ipynb'
)
assert len(episodes_val) >= 5, (
    f'MARS val set too small ({len(episodes_val)} episodes, need >= 5) — '
    f'fix user split in 04_user_split_mars.ipynb'
)
print(f'[CELL 05-04] Episode count assertions PASSED '
      f'(val={len(episodes_val)}, test={len(episodes_test)})')

cell_end('CELL 05-04', t0)
# Out:
# [CELL 05-04] Build episodes K=5 Q=10
# [CELL 05-04] train: 111 episodes, 9 users
# [CELL 05-04] val: 6 episodes, 6 users
# [CELL 05-04] test: 17 episodes, 17 users
# [CELL 05-04] Episode count assertions PASSED (val=6, test=17)
# [CELL 05-04] elapsed=0.07s  done

# %%
# [CELL 05-05] Validate chronological ordering

t0 = cell_start('CELL 05-05', 'Validate chronological ordering')

for name, df in [('train', episodes_train), ('val', episodes_val), ('test', episodes_test)]:
    violations = df[df['support_max_ts'] >= df['query_min_ts']]
    if len(violations) > 0:
        raise RuntimeError(
            f'{name}: {len(violations)} chronological violations!\n'
            f'support_max_ts must be strictly less than query_min_ts for all episodes.'
        )
    print(f'[CELL 05-05] {name}: all {len(df):,} episodes chronologically valid '
          f'(support_max_ts < query_min_ts)')

cell_end('CELL 05-05', t0)
# Out:
# [CELL 05-05] Validate chronological ordering
# [CELL 05-05] train: all 111 episodes chronologically valid (support_max_ts < query_min_ts)
# [CELL 05-05] val: all 6 episodes chronologically valid (support_max_ts < query_min_ts)
# [CELL 05-05] test: all 17 episodes chronologically valid (support_max_ts < query_min_ts)
# [CELL 05-05] elapsed=0.00s  done

# %%
# [CELL 05-06] Save parquets + register DuckDB views + save report

t0 = cell_start('CELL 05-06', 'Save + register DuckDB views')

episodes_train.to_parquet(OUT_EPS_TRAIN, index=False, compression='zstd')
episodes_val.to_parquet(OUT_EPS_VAL,   index=False, compression='zstd')
episodes_test.to_parquet(OUT_EPS_TEST,  index=False, compression='zstd')

for name, path in [('train', OUT_EPS_TRAIN), ('val', OUT_EPS_VAL), ('test', OUT_EPS_TEST)]:
    print(f'[CELL 05-06] Saved episodes_{name}: {path.stat().st_size/(1<<20):.2f} MB')

def esc(p): return str(p).replace("'","''")
PATHS['DATA_INTERIM'].mkdir(parents=True, exist_ok=True)
con = duckdb.connect(str(DUCKDB_PATH), read_only=False)
for split, path in [('train', OUT_EPS_TRAIN), ('val', OUT_EPS_VAL), ('test', OUT_EPS_TEST)]:
    vname = f'mars_episodes_{split}_K{K_SUPPORT}_Q{Q_QUERY}'
    con.execute(f'DROP VIEW IF EXISTS {vname};')
    con.execute(f"CREATE VIEW {vname} AS SELECT * FROM read_parquet('{esc(path)}')")
    n = con.execute(f'SELECT COUNT(*) FROM {vname}').fetchone()[0]
    print(f'[CELL 05-06] {vname}: {n:,}')
con.close()

# Update report
r = read_json(REPORT_PATH)
r['metrics'] = {
    'K': K_SUPPORT, 'Q': Q_QUERY,
    'n_episodes_train': len(episodes_train),
    'n_episodes_val':   len(episodes_val),
    'n_episodes_test':  len(episodes_test),
}
r['key_findings'] = [
    f'Train episodes: {len(episodes_train):,}',
    f'Val episodes:   {len(episodes_val):,} (>= 50 required)',
    f'Test episodes:  {len(episodes_test):,} (>= 50 required)',
    f'Protocol: K={K_SUPPORT} support + Q={Q_QUERY} query, chronological no-leakage',
]
write_json_atomic(REPORT_PATH, r)

# Update manifest
mf = read_json(MANIFEST_PATH)
mf['artifacts'] = [
    {'name': 'episodes_train', 'path': str(OUT_EPS_TRAIN)},
    {'name': 'episodes_val',   'path': str(OUT_EPS_VAL)},
    {'name': 'episodes_test',  'path': str(OUT_EPS_TEST)},
]
write_json_atomic(MANIFEST_PATH, mf)

cell_end('CELL 05-06', t0)
# Out:
# [CELL 05-06] Save + register DuckDB views
# [CELL 05-06] Saved episodes_train: 0.01 MB
# [CELL 05-06] Saved episodes_val: 0.01 MB
# [CELL 05-06] Saved episodes_test: 0.01 MB
# [CELL 05-06] mars_episodes_train_K5_Q10: 111
# [CELL 05-06] mars_episodes_val_K5_Q10: 6
# [CELL 05-06] mars_episodes_test_K5_Q10: 17
# [CELL 05-06] elapsed=0.38s  done

# %% [markdown]
# ## Notebook 05 Complete
#
# Episodes built (K=5, Q=10). Chronological ordering validated. Both val and test sets have >= 50 episodes.
#
# **Next:** `06_base_model_selection_mars.ipynb` → produces `gru_global_mars.pth`.
