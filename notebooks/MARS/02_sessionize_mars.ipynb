# %% [markdown]
# # Notebook 02: Sessionize MARS
#
# **Purpose:** Interactions → sessions using 30-min inactivity gap, min 2 events per session.
#
# **Inputs:**
# - `data/interim/mars/interactions.parquet`
#
# **Outputs:**
# - `data/processed/mars/events_sessionized.parquet`
# - `data/processed/mars/sessions/sessions.parquet`
# - `data/interim/mars.duckdb` (view: `mars_events_sessionized`)
# - `reports/02_sessionize_mars/<run_tag>/report.json`
#
# **Protocol:** 30-min gap threshold; sessions with < 2 events are discarded.

# %%
# [CELL 02-00] Bootstrap

import json
import time
import uuid
import hashlib
from pathlib import Path
from datetime import datetime
from typing import Any

import numpy as np
import pandas as pd

def find_repo_root(start):
    for p in [Path(start).resolve(), *Path(start).resolve().parents]:
        if (p / 'PROJECT_STATE.md').exists(): return p
    raise RuntimeError('PROJECT_STATE.md not found')

REPO_ROOT = find_repo_root(Path.cwd())
PATHS = {
    'META_REGISTRY':  REPO_ROOT / 'meta.json',
    'DATA_INTERIM':   REPO_ROOT / 'data' / 'interim',
    'DATA_PROCESSED': REPO_ROOT / 'data' / 'processed',
    'REPORTS':        REPO_ROOT / 'reports',
}

def cell_start(cid, title, **kw):
    t = time.time()
    print(f'\n[{cid}] {title}')
    print(f'[{cid}] start={datetime.now().isoformat(timespec="seconds")}')
    for k, v in kw.items(): print(f'[{cid}] {k}={v}')
    return t

def cell_end(cid, t0, **kw):
    for k, v in kw.items(): print(f'[{cid}] {k}={v}')
    print(f'[{cid}] elapsed={time.time()-t0:.2f}s  done')

def write_json_atomic(path, obj, indent=2):
    path = Path(path); path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + f'.tmp_{uuid.uuid4().hex}')
    tmp.write_text(json.dumps(obj, ensure_ascii=False, indent=indent), encoding='utf-8')
    tmp.replace(path)

def read_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

def sha256_file(path):
    h = hashlib.sha256()
    with open(path, 'rb') as f:
        while chunk := f.read(1 << 20): h.update(chunk)
    return h.hexdigest()

print(f'[CELL 02-00] REPO_ROOT={REPO_ROOT}')
print('[CELL 02-00] done')
# Out:
# [CELL 02-00] REPO_ROOT=/home/user/jamalla/anonymous-users-mooc-session-meta
# [CELL 02-00] done

# %%
# [CELL 02-01] Seed + run config

import random

GLOBAL_SEED = 20260107
random.seed(GLOBAL_SEED)
np.random.seed(GLOBAL_SEED)

NOTEBOOK_NAME      = '02_sessionize_mars'
DATASET            = 'mars'
GAP_THRESHOLD      = 30 * 60   # 1800 seconds
MIN_SESSION_EVENTS = 2

RUN_TAG = datetime.now().strftime('%Y%m%d_%H%M%S')
RUN_ID  = uuid.uuid4().hex

OUT_DIR       = PATHS['REPORTS'] / NOTEBOOK_NAME / RUN_TAG
OUT_DIR.mkdir(parents=True, exist_ok=True)
REPORT_PATH   = OUT_DIR / 'report.json'
CONFIG_PATH   = OUT_DIR / 'config.json'
MANIFEST_PATH = OUT_DIR / 'manifest.json'

IN_PARQUET = PATHS['DATA_INTERIM'] / 'mars' / 'interactions.parquet'
DUCKDB_PATH = PATHS['DATA_INTERIM'] / 'mars.duckdb'

SESSIONS_DIR = PATHS['DATA_PROCESSED'] / 'mars' / 'sessions'
SESSIONS_DIR.mkdir(parents=True, exist_ok=True)
OUT_EVENTS_PARQUET   = PATHS['DATA_PROCESSED'] / 'mars' / 'events_sessionized.parquet'
OUT_SESSIONS_PARQUET = SESSIONS_DIR / 'sessions.parquet'

CFG = {
    'notebook': NOTEBOOK_NAME, 'dataset': DATASET,
    'run_id': RUN_ID, 'run_tag': RUN_TAG, 'seed': GLOBAL_SEED,
    'sessionization': {
        'gap_threshold_seconds': GAP_THRESHOLD,
        'min_events_per_session': MIN_SESSION_EVENTS,
    },
}
write_json_atomic(CONFIG_PATH, CFG)

for path, obj in [
    (REPORT_PATH, {'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG,
                   'created_at': datetime.now().isoformat(timespec='seconds'),
                   'metrics': {}, 'key_findings': [], 'sanity_samples': {},
                   'data_fingerprints': {}, 'notes': []}),
    (MANIFEST_PATH, {'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG, 'artifacts': []}),
]:
    write_json_atomic(path, obj)

META = PATHS['META_REGISTRY']
if not META.exists(): write_json_atomic(META, {'schema_version': 1, 'runs': []})
m = read_json(META)
m['runs'].append({'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG, 'out_dir': str(OUT_DIR)})
write_json_atomic(META, m)

print(f'[CELL 02-01] GLOBAL_SEED={GLOBAL_SEED}  GAP_THRESHOLD={GAP_THRESHOLD}s  MIN_SESSION_EVENTS={MIN_SESSION_EVENTS}')
print(f'[CELL 02-01] RUN_TAG={RUN_TAG}')
print('[CELL 02-01] done')
# Out:
# [CELL 02-01] GLOBAL_SEED=20260107  GAP_THRESHOLD=1800s  MIN_SESSION_EVENTS=2
# [CELL 02-01] RUN_TAG=20260409_180725
# [CELL 02-01] done

# %%
# [CELL 02-02] Load interactions.parquet

t0 = cell_start('CELL 02-02', 'Load interactions.parquet', path=str(IN_PARQUET))

if not IN_PARQUET.exists():
    raise RuntimeError(f'Missing {IN_PARQUET}. Run 01_ingest_mars.ipynb first.')

df = pd.read_parquet(IN_PARQUET)

print(f'[CELL 02-02] Shape: {df.shape}')
print(f'[CELL 02-02] Columns: {list(df.columns)}')
print(f'[CELL 02-02] n_users: {df["user_id"].nunique():,}')
print(f'[CELL 02-02] n_items: {df["item_id"].nunique():,}')
print(df.head(3).to_string(index=False))

cell_end('CELL 02-02', t0, n_rows=int(len(df)))
# Out:
# [CELL 02-02] Load interactions.parquet
# [CELL 02-02] start=2026-04-09T18:07:25
# [CELL 02-02] path=/home/user/jamalla/anonymous-users-mooc-session-meta/data/interim/mars/interactions.parquet
# [CELL 02-02] Shape: (3655, 5)
# [CELL 02-02] Columns: ['user_id', 'item_id', 'ts_epoch', 'watch_percentage', 'rating']
# [CELL 02-02] n_users: 822
# [CELL 02-02] n_items: 776
#  user_id  item_id   ts_epoch  watch_percentage  rating
#      672      538 1540892762               100      10
#      672      815 1540893320               100      10
#      672     7105 1540893584               100      10
# [CELL 02-02] n_rows=3655
# [CELL 02-02] elapsed=0.06s  done

# %%
# [CELL 02-03] Sessionize: 30-min gap threshold + min events filter

t0 = cell_start('CELL 02-03', 'Sessionize', gap_threshold_sec=GAP_THRESHOLD, min_events=MIN_SESSION_EVENTS)

# Sort by user_id, ts_epoch
df = df.sort_values(['user_id', 'ts_epoch']).reset_index(drop=True)

# Compute time gap to previous event within each user
df['prev_ts_epoch'] = df.groupby('user_id')['ts_epoch'].shift(1)
df['inter_gap']     = df['ts_epoch'] - df['prev_ts_epoch']

# New session: first event for user OR gap > threshold
df['is_new_session'] = df['prev_ts_epoch'].isna() | (df['inter_gap'] > GAP_THRESHOLD)

# session_id = globally unique integer (cumsum across whole sorted dataframe)
df['session_id'] = df['is_new_session'].cumsum().astype(int) - 1  # 0-indexed

n_sessions_raw = int(df['session_id'].nunique())
print(f'[CELL 02-03] Sessions before min-events filter: {n_sessions_raw:,}')

# Filter: keep only sessions with >= MIN_SESSION_EVENTS events
sess_len = df.groupby('session_id').size()
valid_sessions = sess_len[sess_len >= MIN_SESSION_EVENTS].index
df = df[df['session_id'].isin(valid_sessions)].reset_index(drop=True)

n_sessions_final = int(df['session_id'].nunique())
n_dropped = n_sessions_raw - n_sessions_final

print(f'[CELL 02-03] Sessions after filter (>={MIN_SESSION_EVENTS} events): {n_sessions_final:,}')
print(f'[CELL 02-03] Dropped {n_dropped:,} sessions with < {MIN_SESSION_EVENTS} events')
print(f'[CELL 02-03] Remaining events: {len(df):,}')

cell_end('CELL 02-03', t0, n_sessions=n_sessions_final, n_events=int(len(df)))
# Out:
# [CELL 02-03] Sessionize
# [CELL 02-03] start=2026-04-09T18:07:26
# [CELL 02-03] gap_threshold_sec=1800
# [CELL 02-03] min_events=2
# [CELL 02-03] Sessions before min-events filter: 1,322
# [CELL 02-03] Sessions after filter (>=2 events): 561
# [CELL 02-03] Dropped 761 sessions with < 2 events
# [CELL 02-03] Remaining events: 2,894
# [CELL 02-03] n_sessions=561
# [CELL 02-03] n_events=2894
# [CELL 02-03] elapsed=0.01s  done

# %%
# [CELL 02-04] Compute session-level stats

t0 = cell_start('CELL 02-04', 'Compute session-level stats')

sessions = df.groupby('session_id').agg(
    user_id        = ('user_id',  'first'),
    n_events       = ('item_id',  'count'),
    start_ts       = ('ts_epoch', 'min'),
    end_ts         = ('ts_epoch', 'max'),
    n_unique_items = ('item_id',  'nunique'),
).reset_index()

sessions['duration_sec'] = sessions['end_ts'] - sessions['start_ts']

print(f'[CELL 02-04] Sessions shape: {sessions.shape}')
print(f'[CELL 02-04] Columns: {list(sessions.columns)}')

print(f'\n[CELL 02-04] n_events per session:')
print(f'  min={sessions["n_events"].min()}  p50={sessions["n_events"].quantile(.5):.0f}  p90={sessions["n_events"].quantile(.9):.0f}  max={sessions["n_events"].max()}')

print(f'[CELL 02-04] duration_sec per session:')
print(f'  min={sessions["duration_sec"].min():.0f}  p50={sessions["duration_sec"].quantile(.5):.0f}  p90={sessions["duration_sec"].quantile(.9):.0f}  max={sessions["duration_sec"].max():.0f}')

print(f'[CELL 02-04] n_unique_items per session:')
print(f'  min={sessions["n_unique_items"].min()}  p50={sessions["n_unique_items"].quantile(.5):.0f}  p90={sessions["n_unique_items"].quantile(.9):.0f}  max={sessions["n_unique_items"].max()}')

# Save sessions.parquet
sessions_out_cols = ['session_id', 'user_id', 'n_events', 'duration_sec', 'n_unique_items']
sessions[sessions_out_cols].to_parquet(OUT_SESSIONS_PARQUET, index=False, compression='zstd')
sessions_bytes = int(OUT_SESSIONS_PARQUET.stat().st_size)
sessions_sha   = sha256_file(OUT_SESSIONS_PARQUET)
print(f'\n[CELL 02-04] Saved: {OUT_SESSIONS_PARQUET} ({sessions_bytes / 1024**2:.2f} MB)')
print(f'[CELL 02-04] SHA256: {sessions_sha}')

cell_end('CELL 02-04', t0, n_sessions=int(len(sessions)))
# Out:
# [CELL 02-04] Compute session-level stats
# [CELL 02-04] start=2026-04-09T18:07:26
# [CELL 02-04] Sessions shape: (561, 7)
# [CELL 02-04] Columns: ['session_id', 'user_id', 'n_events', 'start_ts', 'end_ts', 'n_unique_items', 'duration_sec']
#
# [CELL 02-04] n_events per session:
#   min=2  p50=3  p90=11  max=50
# [CELL 02-04] duration_sec per session:
#   min=2  p50=500  p90=2624  max=13098
# [CELL 02-04] n_unique_items per session:
#   min=2  p50=3  p90=11  max=50
#
# [CELL 02-04] Saved: /home/user/jamalla/anonymous-users-mooc-session-meta/data/processed/mars/sessions/sessions.parquet (0.01 MB)
# [CELL 02-04] SHA256: d8f8fdb73ed68fac00a3899bf354a7c0cf8177259cb946d69453519c325f6244
# [CELL 02-04] n_sessions=561
# [CELL 02-04] elapsed=0.01s  done

# %%
# [CELL 02-05] Save events_sessionized.parquet + register DuckDB view + print summary + save report

import duckdb

t0 = cell_start('CELL 02-05', 'Save events + register DuckDB view + save report')

# Build events output: keep relevant columns
out_cols = ['user_id', 'item_id', 'ts_epoch', 'session_id']
# Optionally include watch_percentage and rating if present
for opt_col in ['watch_percentage', 'rating']:
    if opt_col in df.columns:
        out_cols.append(opt_col)

events_out = df[out_cols].copy()

# Save events_sessionized.parquet
OUT_EVENTS_PARQUET.parent.mkdir(parents=True, exist_ok=True)
events_out.to_parquet(OUT_EVENTS_PARQUET, index=False, compression='zstd')
events_bytes = int(OUT_EVENTS_PARQUET.stat().st_size)
events_sha   = sha256_file(OUT_EVENTS_PARQUET)

print(f'[CELL 02-05] Saved: {OUT_EVENTS_PARQUET} ({events_bytes / 1024**2:.2f} MB)')
print(f'[CELL 02-05] SHA256: {events_sha}')
print(f'[CELL 02-05] Columns: {list(events_out.columns)}')

# Register DuckDB view
def esc(p): return str(p).replace("'", "''")

con = duckdb.connect(str(DUCKDB_PATH), read_only=False)
con.execute('DROP VIEW IF EXISTS mars_events_sessionized;')
con.execute(f"CREATE VIEW mars_events_sessionized AS SELECT * FROM read_parquet('{esc(OUT_EVENTS_PARQUET)}')")
n_view = int(con.execute('SELECT COUNT(*) FROM mars_events_sessionized').fetchone()[0])
con.close()

print(f'[CELL 02-05] DuckDB view mars_events_sessionized: {n_view:,} rows')

# Summary stats
user_stats = events_out.groupby('user_id').agg(
    n_sessions=('session_id', 'nunique'),
    n_events=('item_id', 'count'),
).reset_index()

print(f'\n[CELL 02-05] Summary:')
print(f'  n_users:    {user_stats.shape[0]:,}')
print(f'  n_sessions: {events_out["session_id"].nunique():,}')
print(f'  n_events:   {len(events_out):,}')
print(f'  n_items:    {events_out["item_id"].nunique():,}')

print(f'\n[CELL 02-05] Sessions per user:')
print(f'  min={user_stats["n_sessions"].min()}  p50={user_stats["n_sessions"].quantile(.5):.0f}  p90={user_stats["n_sessions"].quantile(.9):.0f}  max={user_stats["n_sessions"].max()}')

# Cold-start eligibility check
MIN_PAIRS = 15  # K=5 support + Q=10 query
elig = user_stats[user_stats['n_events'] >= MIN_PAIRS]
proj_test = int(len(elig) * 0.15)
print(f'\n[CELL 02-05] Cold-start eligibility (>={MIN_PAIRS} events): {len(elig):,} users ({len(elig)/len(user_stats)*100:.1f}%)')
print(f'[CELL 02-05] Projected test users (15% split): ~{proj_test:,}')
if proj_test < 50:
    print('[CELL 02-05] WARNING: < 50 projected test users — may need to adjust split')
else:
    print(f'[CELL 02-05] OK: sufficient users for meta-learning evaluation')

# Update report
report = read_json(REPORT_PATH)
report['metrics'] = {
    'n_events':             int(len(events_out)),
    'n_sessions':           int(events_out['session_id'].nunique()),
    'n_users':              int(user_stats.shape[0]),
    'n_items':              int(events_out['item_id'].nunique()),
    'gap_threshold_sec':    GAP_THRESHOLD,
    'min_events_per_session': MIN_SESSION_EVENTS,
    'n_eligible_users':     int(len(elig)),
    'proj_test_users':      proj_test,
}
report['sanity_samples']['events_head3']   = events_out.head(3).to_dict(orient='records')
report['sanity_samples']['sessions_head3'] = sessions.head(3)[sessions_out_cols].to_dict(orient='records')
report['data_fingerprints']['events_sessionized'] = {'path': str(OUT_EVENTS_PARQUET), 'bytes': events_bytes, 'sha256': events_sha}
report['data_fingerprints']['sessions']           = {'path': str(OUT_SESSIONS_PARQUET), 'bytes': sessions_bytes, 'sha256': sessions_sha}
report['notes'].append(f'30-min gap threshold; sessions with < {MIN_SESSION_EVENTS} events discarded. Integer session_ids (cumsum).')
write_json_atomic(REPORT_PATH, report)

manifest = read_json(MANIFEST_PATH)
for path in [OUT_EVENTS_PARQUET, OUT_SESSIONS_PARQUET, DUCKDB_PATH]:
    try: sha = sha256_file(path)
    except Exception as e: sha = f'ERROR: {e}'
    manifest['artifacts'].append({'path': str(path), 'bytes': int(path.stat().st_size), 'sha256': sha})
write_json_atomic(MANIFEST_PATH, manifest)

print(f'\n[CELL 02-05] Updated: {REPORT_PATH}')
cell_end('CELL 02-05', t0)
# Out:
# [CELL 02-05] Save events + register DuckDB view + save report
# [CELL 02-05] start=2026-04-09T18:07:26
# [CELL 02-05] Saved: /home/user/jamalla/anonymous-users-mooc-session-meta/data/processed/mars/events_sessionized.parquet (0.03 MB)
# [CELL 02-05] SHA256: 907cfa58598d5900456d8707be3bc8330399055d5ffe0e7100b04fc6e7db1eae
# [CELL 02-05] Columns: ['user_id', 'item_id', 'ts_epoch', 'session_id', 'watch_percentage', 'rating']
# [CELL 02-05] DuckDB view mars_events_sessionized: 2,894 rows
#
# [CELL 02-05] Summary:
#   n_users:    378
#   n_sessions: 561
#   n_events:   2,894
#   n_items:    745
#
# [CELL 02-05] Sessions per user:
#   min=1  p50=1  p90=2  max=15
#
# [CELL 02-05] Cold-start eligibility (>=15 events): 42 users (11.1%)
# [CELL 02-05] Projected test users (15% split): ~6
# [CELL 02-05] WARNING: < 50 projected test users — may need to adjust split
#
# ...

# %% [markdown]
# ## Notebook 02 Complete
#
# **Outputs:**
# - `data/processed/mars/events_sessionized.parquet` — sessionized events (user_id, item_id, ts_epoch, session_id, watch_percentage, rating)
# - `data/processed/mars/sessions/sessions.parquet` — session-level stats (session_id, user_id, n_events, duration_sec, n_unique_items)
# - `data/interim/mars.duckdb` — view: `mars_events_sessionized`
#
# **Next:** `03_vocab_pairs_mars.ipynb` — build item vocabulary + (prefix → next item) pairs
