# %% [markdown]
# # Notebook 01: Ingest MARS
#
# **Purpose:** Raw CSV → cleaned Parquet → DuckDB interim table.
#
# **Inputs:**
# - `data/raw/mars/explicit_ratings_en.csv` — columns: user_id, item_id, watch_percentage, created_at, rating
#
# **Outputs:**
# - `data/interim/mars/interactions.parquet`
# - `data/interim/mars.duckdb` (view: `mars_interactions`)
# - `reports/01_ingest_mars/<run_tag>/report.json`
#
# **Strategy:**
# - Parse timestamps → ts_epoch (Unix seconds)
# - Deduplicate on (user_id, item_id, ts_epoch)
# - Sort by user_id, ts_epoch

# %%
# [CELL 01-00] Bootstrap: repo root + paths + helpers

import json
import time
import uuid
import hashlib
from pathlib import Path
from datetime import datetime
from typing import Any

import numpy as np
import pandas as pd

def find_repo_root(start):
    for p in [Path(start).resolve(), *Path(start).resolve().parents]:
        if (p / 'PROJECT_STATE.md').exists(): return p
    raise RuntimeError('PROJECT_STATE.md not found')

REPO_ROOT = find_repo_root(Path.cwd())

PATHS = {
    'META_REGISTRY':  REPO_ROOT / 'meta.json',
    'DATA_RAW':       REPO_ROOT / 'data' / 'raw',
    'DATA_INTERIM':   REPO_ROOT / 'data' / 'interim',
    'DATA_PROCESSED': REPO_ROOT / 'data' / 'processed',
    'REPORTS':        REPO_ROOT / 'reports',
}

def cell_start(cid, title, **kw):
    t = time.time()
    print(f'\n[{cid}] {title}')
    print(f'[{cid}] start={datetime.now().isoformat(timespec="seconds")}')
    for k, v in kw.items(): print(f'[{cid}] {k}={v}')
    return t

def cell_end(cid, t0, **kw):
    for k, v in kw.items(): print(f'[{cid}] {k}={v}')
    print(f'[{cid}] elapsed={time.time()-t0:.2f}s  done')

def write_json_atomic(path, obj, indent=2):
    path = Path(path); path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_suffix(path.suffix + f'.tmp_{uuid.uuid4().hex}')
    tmp.write_text(json.dumps(obj, ensure_ascii=False, indent=indent), encoding='utf-8')
    tmp.replace(path)

def read_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

def sha256_file(path):
    h = hashlib.sha256()
    with open(path, 'rb') as f:
        while chunk := f.read(1 << 20): h.update(chunk)
    return h.hexdigest()

print(f'[CELL 01-00] REPO_ROOT={REPO_ROOT}')
for k, v in PATHS.items(): print(f'[CELL 01-00] {k}={v}')
print('[CELL 01-00] done')
# Out:
# [CELL 01-00] REPO_ROOT=/home/user/jamalla/anonymous-users-mooc-session-meta
# [CELL 01-00] META_REGISTRY=/home/user/jamalla/anonymous-users-mooc-session-meta/meta.json
# [CELL 01-00] DATA_RAW=/home/user/jamalla/anonymous-users-mooc-session-meta/data/raw
# [CELL 01-00] DATA_INTERIM=/home/user/jamalla/anonymous-users-mooc-session-meta/data/interim
# [CELL 01-00] DATA_PROCESSED=/home/user/jamalla/anonymous-users-mooc-session-meta/data/processed
# [CELL 01-00] REPORTS=/home/user/jamalla/anonymous-users-mooc-session-meta/reports
# [CELL 01-00] done

# %%
# [CELL 01-01] Seed + run config

import random

GLOBAL_SEED = 20260107
random.seed(GLOBAL_SEED)
np.random.seed(GLOBAL_SEED)

NOTEBOOK_NAME = '01_ingest_mars'
DATASET       = 'mars'
RUN_TAG       = datetime.now().strftime('%Y%m%d_%H%M%S')
RUN_ID        = uuid.uuid4().hex

OUT_DIR       = PATHS['REPORTS'] / NOTEBOOK_NAME / RUN_TAG
OUT_DIR.mkdir(parents=True, exist_ok=True)
REPORT_PATH   = OUT_DIR / 'report.json'
CONFIG_PATH   = OUT_DIR / 'config.json'
MANIFEST_PATH = OUT_DIR / 'manifest.json'

RAW_CSV       = PATHS['DATA_RAW'] / 'mars' / 'explicit_ratings_en.csv'
INTERIM_DIR   = PATHS['DATA_INTERIM'] / 'mars'
INTERIM_DIR.mkdir(parents=True, exist_ok=True)
OUT_PARQUET   = INTERIM_DIR / 'interactions.parquet'
DUCKDB_PATH   = PATHS['DATA_INTERIM'] / 'mars.duckdb'

CFG = {
    'notebook': NOTEBOOK_NAME, 'dataset': DATASET,
    'run_id': RUN_ID, 'run_tag': RUN_TAG, 'seed': GLOBAL_SEED,
    'paths': {
        'raw_csv':    str(RAW_CSV),
        'out_parquet': str(OUT_PARQUET),
        'out_duckdb':  str(DUCKDB_PATH),
        'out_dir':     str(OUT_DIR),
    },
    'ingest': {
        'source_columns': ['user_id', 'item_id', 'watch_percentage', 'created_at', 'rating'],
        'dedup_keys':     ['user_id', 'item_id', 'ts_epoch'],
        'parquet_compression': 'zstd',
        'duckdb_view': 'mars_interactions',
    }
}
write_json_atomic(CONFIG_PATH, CFG)

report = {
    'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG,
    'created_at': datetime.now().isoformat(timespec='seconds'),
    'repo_root': str(REPO_ROOT), 'metrics': {}, 'key_findings': [],
    'sanity_samples': {}, 'data_fingerprints': {}, 'notes': [],
}
write_json_atomic(REPORT_PATH, report)
write_json_atomic(MANIFEST_PATH, {'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG, 'artifacts': []})

META_PATH = PATHS['META_REGISTRY']
if not META_PATH.exists(): write_json_atomic(META_PATH, {'schema_version': 1, 'runs': []})
meta = read_json(META_PATH)
meta['runs'].append({'run_id': RUN_ID, 'notebook': NOTEBOOK_NAME, 'run_tag': RUN_TAG,
                     'out_dir': str(OUT_DIR), 'created_at': datetime.now().isoformat(timespec='seconds')})
write_json_atomic(META_PATH, meta)

print(f'[CELL 01-01] GLOBAL_SEED={GLOBAL_SEED}  RUN_TAG={RUN_TAG}')
print(f'[CELL 01-01] OUT_DIR={OUT_DIR}')
print('[CELL 01-01] done')
# Out:
# [CELL 01-01] GLOBAL_SEED=20260107  RUN_TAG=20260409_180531
# [CELL 01-01] OUT_DIR=/home/user/jamalla/anonymous-users-mooc-session-meta/reports/01_ingest_mars/20260409_180531
# [CELL 01-01] done

# %%
# [CELL 01-02] Load raw CSV

t0 = cell_start('CELL 01-02', 'Load raw CSV', path=str(RAW_CSV))

if not RAW_CSV.exists():
    raise RuntimeError(
        f'Raw file not found: {RAW_CSV}\n'
        f'Expected: data/raw/mars/explicit_ratings_en.csv'
    )

df = pd.read_csv(RAW_CSV)

print(f'[CELL 01-02] Shape:   {df.shape}')
print(f'[CELL 01-02] Columns: {list(df.columns)}')
print(f'[CELL 01-02] Dtypes:')
for col, dtype in df.dtypes.items():
    print(f'  {col}: {dtype}')
print(f'\n[CELL 01-02] Head:')
print(df.head(5).to_string(index=False))

cell_end('CELL 01-02', t0, n_rows=int(df.shape[0]), n_cols=int(df.shape[1]))
# Out:
# [CELL 01-02] Load raw CSV
# [CELL 01-02] start=2026-04-09T18:05:31
# [CELL 01-02] path=/home/user/jamalla/anonymous-users-mooc-session-meta/data/raw/mars/explicit_ratings_en.csv
# [CELL 01-02] Shape:   (3659, 5)
# [CELL 01-02] Columns: ['user_id', 'item_id', 'watch_percentage', 'created_at', 'rating']
# [CELL 01-02] Dtypes:
#   user_id: int64
#   item_id: int64
#   watch_percentage: int64
#   created_at: object
#   rating: int64
#
# [CELL 01-02] Head:
#  user_id  item_id  watch_percentage          created_at  rating
#   224557      510               100 2018-09-28 16:18:29      10
#   224557      615               100 2018-09-28 16:22:22      10
#   224557     7680               100 2018-09-28 16:23:34      10
#   224293      510               100 2018-09-28 17:20:30      10
#   224293      515               100 2018-09-28 17:40:02      10
# [CELL 01-02] n_rows=3659
# [CELL 01-02] n_cols=5
# [CELL 01-02] elapsed=0.02s  done

# %%
# [CELL 01-03] Data exploration

t0 = cell_start('CELL 01-03', 'Data exploration')

n_users        = int(df['user_id'].nunique())
n_items        = int(df['item_id'].nunique())
n_interactions = int(len(df))

print(f'[CELL 01-03] n_users:        {n_users:,}')
print(f'[CELL 01-03] n_items:        {n_items:,}')
print(f'[CELL 01-03] n_interactions: {n_interactions:,}')
print(f'[CELL 01-03] density:        {n_interactions / (n_users * n_items):.6f}')

# Rating distribution
if 'rating' in df.columns:
    print(f'\n[CELL 01-03] Rating distribution:')
    print(df['rating'].value_counts().sort_index().to_string())
    print(f'  mean={df["rating"].mean():.3f}  std={df["rating"].std():.3f}')
    print(f'  null ratings: {df["rating"].isna().sum()}')

# watch_percentage stats
if 'watch_percentage' in df.columns:
    wp = df['watch_percentage'].dropna()
    print(f'\n[CELL 01-03] watch_percentage stats:')
    print(f'  count={len(wp):,}  null={df["watch_percentage"].isna().sum()}')
    print(f'  min={wp.min():.3f}  p25={wp.quantile(.25):.3f}  p50={wp.quantile(.5):.3f}')
    print(f'  p75={wp.quantile(.75):.3f}  p90={wp.quantile(.9):.3f}  max={wp.max():.3f}')

# Interactions per user
user_counts = df.groupby('user_id').size()
print(f'\n[CELL 01-03] Interactions per user:')
print(f'  min={user_counts.min()}  p50={user_counts.quantile(.5):.0f}  p90={user_counts.quantile(.9):.0f}  max={user_counts.max()}')

# Interactions per item
item_counts = df.groupby('item_id').size()
print(f'[CELL 01-03] Interactions per item:')
print(f'  min={item_counts.min()}  p50={item_counts.quantile(.5):.0f}  p90={item_counts.quantile(.9):.0f}  max={item_counts.max()}')

cell_end('CELL 01-03', t0, n_users=n_users, n_items=n_items, n_interactions=n_interactions)
# Out:
# [CELL 01-03] Data exploration
# [CELL 01-03] start=2026-04-09T18:05:31
# [CELL 01-03] n_users:        822
# [CELL 01-03] n_items:        776
# [CELL 01-03] n_interactions: 3,659
# [CELL 01-03] density:        0.005736
#
# [CELL 01-03] Rating distribution:
# rating
# 1      200
# 2      135
# 3       90
# 4      105
# 5       61
# 6       74
# 7       72
# 8       79
# 9       96
# 10    2747
#   mean=8.576  std=2.834
#   null ratings: 0
#
# [CELL 01-03] watch_percentage stats:
#   count=3,659  null=0
#   min=0.000  p25=91.000  p50=100.000
#   p75=100.000  p90=100.000  max=100.000
#
# [CELL 01-03] Interactions per user:
#   min=1  p50=2  p90=8  max=134
# [CELL 01-03] Interactions per item:
#   min=1  p50=2  p90=8  max=179
# [CELL 01-03] n_users=822
# [CELL 01-03] n_items=776
# [CELL 01-03] n_interactions=3659
# [CELL 01-03] elapsed=0.01s  done

# %%
# [CELL 01-04] Parse timestamps + deduplicate + sort

t0 = cell_start('CELL 01-04', 'Parse timestamps + deduplicate + sort')

n_before = len(df)

# Parse created_at → ts_epoch (Unix seconds)
df['ts_epoch'] = pd.to_datetime(df['created_at']).astype('int64') // 10**9

print(f'[CELL 01-04] ts_epoch range: {df["ts_epoch"].min()} → {df["ts_epoch"].max()}')
ts_min = pd.to_datetime(df['ts_epoch'], unit='s').min()
ts_max = pd.to_datetime(df['ts_epoch'], unit='s').max()
print(f'[CELL 01-04] Date range: {ts_min.date()} → {ts_max.date()}')
print(f'[CELL 01-04] Span: {(ts_max - ts_min).days} days')

# Remove duplicates on (user_id, item_id, ts_epoch)
df = df.drop_duplicates(subset=['user_id', 'item_id', 'ts_epoch'])
n_after_dedup = len(df)
print(f'[CELL 01-04] Rows before dedup: {n_before:,}')
print(f'[CELL 01-04] Rows after dedup:  {n_after_dedup:,}  (removed {n_before - n_after_dedup:,})')

# Sort by user_id, ts_epoch
df = df.sort_values(['user_id', 'ts_epoch']).reset_index(drop=True)

print(f'[CELL 01-04] Final shape: {df.shape}')
print(f'[CELL 01-04] Columns: {list(df.columns)}')

cell_end('CELL 01-04', t0, n_rows=int(len(df)), n_dedup_removed=int(n_before - n_after_dedup))
# Out:
# [CELL 01-04] Parse timestamps + deduplicate + sort
# [CELL 01-04] start=2026-04-09T18:05:31
# [CELL 01-04] ts_epoch range: 1538145495 → 1632155166
# [CELL 01-04] Date range: 2018-09-28 → 2021-09-20
# [CELL 01-04] Span: 1088 days
# [CELL 01-04] Rows before dedup: 3,659
# [CELL 01-04] Rows after dedup:  3,655  (removed 4)
# [CELL 01-04] Final shape: (3655, 6)
# [CELL 01-04] Columns: ['user_id', 'item_id', 'watch_percentage', 'created_at', 'rating', 'ts_epoch']
# [CELL 01-04] n_rows=3655
# [CELL 01-04] n_dedup_removed=4
# [CELL 01-04] elapsed=0.01s  done

# %%
# [CELL 01-05] Save interactions.parquet + register DuckDB view + save report

import duckdb

t0 = cell_start('CELL 01-05', 'Save Parquet + register DuckDB view')

# Select and order output columns
out_cols = ['user_id', 'item_id', 'ts_epoch', 'watch_percentage', 'rating']
# Only keep columns that actually exist
out_cols = [c for c in out_cols if c in df.columns]
df_out = df[out_cols].copy()

df_out.to_parquet(OUT_PARQUET, index=False, compression='zstd')
parq_bytes = int(OUT_PARQUET.stat().st_size)
parq_sha   = sha256_file(OUT_PARQUET)

print(f'[CELL 01-05] Saved: {OUT_PARQUET}')
print(f'[CELL 01-05] Size:  {parq_bytes / 1024**2:.1f} MB')
print(f'[CELL 01-05] SHA256: {parq_sha}')
print(f'[CELL 01-05] Output columns: {list(df_out.columns)}')

# Register DuckDB view
def esc(p): return str(p).replace("'", "''")

con = duckdb.connect(str(DUCKDB_PATH), read_only=False)
con.execute('DROP VIEW IF EXISTS mars_interactions;')
con.execute(f"CREATE VIEW mars_interactions AS SELECT * FROM read_parquet('{esc(OUT_PARQUET)}')")
n_view = int(con.execute('SELECT COUNT(*) FROM mars_interactions').fetchone()[0])
schema_df = con.execute('DESCRIBE mars_interactions').fetchdf()
con.close()

print(f'[CELL 01-05] DuckDB view mars_interactions: {n_view:,} rows')
print(schema_df.to_string(index=False))

# Update report
report = read_json(REPORT_PATH)
report['metrics'] = {
    'n_interactions': int(len(df_out)),
    'n_users':        int(df_out['user_id'].nunique()),
    'n_items':        int(df_out['item_id'].nunique()),
    'n_dedup_removed': int(n_before - n_after_dedup),
}
report['sanity_samples']['head5'] = df_out.head(5).to_dict(orient='records')
report['data_fingerprints']['interactions_parquet'] = {
    'path': str(OUT_PARQUET), 'bytes': parq_bytes, 'sha256': parq_sha
}
report['notes'].append('Columns: user_id, item_id, ts_epoch, watch_percentage, rating. Deduped on (user_id, item_id, ts_epoch).')
write_json_atomic(REPORT_PATH, report)

# Update manifest
manifest = read_json(MANIFEST_PATH)
for path in [OUT_PARQUET, DUCKDB_PATH]:
    try: sha = sha256_file(path)
    except Exception as e: sha = f'ERROR: {e}'
    manifest['artifacts'].append({'path': str(path), 'bytes': int(path.stat().st_size), 'sha256': sha})
write_json_atomic(MANIFEST_PATH, manifest)

print(f'[CELL 01-05] Updated: {REPORT_PATH}')
cell_end('CELL 01-05', t0, n_rows=int(len(df_out)))
# Out:
# [CELL 01-05] Save Parquet + register DuckDB view
# [CELL 01-05] start=2026-04-09T18:05:32
# [CELL 01-05] Saved: /home/user/jamalla/anonymous-users-mooc-session-meta/data/interim/mars/interactions.parquet
# [CELL 01-05] Size:  0.0 MB
# [CELL 01-05] SHA256: cf05565658572e06f057aedeb42a5110e4d16e5dad6e284ccf8923a9fb77bab1
# [CELL 01-05] Output columns: ['user_id', 'item_id', 'ts_epoch', 'watch_percentage', 'rating']
# [CELL 01-05] DuckDB view mars_interactions: 3,655 rows
#      column_name column_type null  key default extra
#          user_id      BIGINT  YES None    None  None
#          item_id      BIGINT  YES None    None  None
#         ts_epoch      BIGINT  YES None    None  None
# watch_percentage      BIGINT  YES None    None  None
#           rating      BIGINT  YES None    None  None
# [CELL 01-05] Updated: /home/user/jamalla/anonymous-users-mooc-session-meta/reports/01_ingest_mars/20260409_180531/report.json
# [CELL 01-05] n_rows=3655
# [CELL 01-05] elapsed=0.23s  done

# %% [markdown]
# ## Notebook 01 Complete
#
# **Outputs:**
# - `data/interim/mars/interactions.parquet` — cleaned interactions (user_id, item_id, ts_epoch, watch_percentage, rating)
# - `data/interim/mars.duckdb` — view: `mars_interactions`
# - `reports/01_ingest_mars/<run_tag>/report.json`
#
# **Next:** `02_sessionize_mars.ipynb` — apply 30-min inactivity gap to form sessions
